# %%
# importing the ramdom module for selecting the random value from given value
import random
# Choices provided for computer as well as user
Choice=["Rock","Paper","Scissor"]
# Using the while for program to run until the condition if Ture
while True:
  user_count=0
  computer_count=0
  for i in range(1,4):
    print("Welcome")
    print("Round",i)
    print("Select: 1] Rock, 2] Paper, 3] Scissor")
# Entering the user guess
    your_choice=int(input("Enter your choice="))

    if (your_choice==1):
      print("You have selected Rock")
      your_choice="Rock"
    elif (your_choice==2):
      print("You have selected Paper")
      your_choice="Paper"
    elif (your_choice==3):
      print("You have selected Scissor")
      your_choice="Scissor"
    else:
      print("Invalid character choosen,choose again")
      break
# Guess by computer by using the random module
    computer_choice= random.choice(Choice)
    print("Computer selects:",computer_choice)
# Condition for choosing the winner
    if (your_choice==computer_choice):
       print("Draw")
    elif ((your_choice=="Rock" and computer_choice=="Scissor") or 
            (your_choice=="Paper" and computer_choice=="Rock") or 
            (your_choice=="Scissor" and computer_choice=="Paper")):
        user_count=user_count+1
    elif ((your_choice=="Rock" and computer_choice=="Paper") or 
            (your_choice=="Paper" and computer_choice=="Scissor") or 
            (your_choice=="Scissor" and computer_choice=="Rock")):
        computer_count=computer_count + 1

  if (user_count < computer_count):
   print("Computer Wins!")
  elif (user_count > computer_count):
   print("You win!")
  else:
   print("Draw")
  print("Do you want to play again")
  x=str(input("Enter Yes or No:"))
  if (x=="Yes" or x=="yes" or x=="YES"):
    continue
  else:
    break
# Out:
# Welcome
# Round 1
# Select: 1] Rock, 2] Paper, 3] Scissor
# Enter your choice=2
# You have selected Paper
# Computer selects: Paper
# Draw
# Welcome
# Round 2
# Select: 1] Rock, 2] Paper, 3] Scissor
# Enter your choice=3
# You have selected Scissor
# Computer selects: Paper
# Welcome
# Round 3
# Select: 1] Rock, 2] Paper, 3] Scissor
# Enter your choice=1
# You have selected Rock
# Computer selects: Rock
# Draw
# You win!
# Do you want to play again
# Enter Yes or No:Yes
# Welcome
# Round 1
# Select: 1] Rock, 2] Paper, 3] Scissor
# Enter your choice=1
# You have selected Rock
# Computer selects: Paper
# Welcome
# Round 2
# Select: 1] Rock, 2] Paper, 3] Scissor
# Enter your choice=3
# You have selected Scissor
# Computer selects: Scissor
# Draw
# Welcome
# Round 3
# Select: 1] Rock, 2] Paper, 3] Scissor
# Enter your choice=3
# You have selected Scissor
# Computer selects: Scissor
# Draw
# Computer Wins!
# Do you want to play again
# Enter Yes or No:No
